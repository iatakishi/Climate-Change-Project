# %% [markdown]
# # 1. Data Uploading Section:

# %%
import pandas as pd
import numpy as np
import os

# %%
#Change the directory

os.chdir("C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Commodity Trade Statistics (Source - Kaggle)")

# %%
#Check the directory

os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Commodity Trade Statistics (Source - Kaggle)'

# %%
#Import commodity trade

commodity_trade = pd.read_csv("C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Commodity Trade Statistics (Source - Kaggle)\\commodity_trade_statistics_data.csv", dtype={'comm_code':'string'})

# %%
#Show commodity trade data

commodity_trade
# Out:
#         country_or_area  year comm_code  \
# 0           Afghanistan  2016    010410
# 1           Afghanistan  2016    010420
# 2           Afghanistan  2008    010210
# 3               Albania  2016    010290
# 4               Albania  2016    010392
# ...                 ...   ...       ...
# 8225866        Zimbabwe  2001     TOTAL
# 8225867        Zimbabwe  2001     TOTAL
# 8225868        Zimbabwe  2000     TOTAL
# 8225869        Zimbabwe  1995     TOTAL
# 8225870        Zimbabwe  1995     TOTAL
#
#                                                commodity       flow  \
# 0                                            Sheep, live     Export
# 1                                            Goats, live     Export
# 2                Bovine animals, live pure-bred breeding     Import
# 3        Bovine animals, live, except pure-bred breeding     Import
# 4          Swine, live except pure-bred breeding > 50 kg     Import
# ...

# %%
#Chnage the directory

os.chdir(r"C:\Users\Idrak\Desktop\Data Science Projects\Climate Change Project\Data\Countries of the World (Source - Kaggle)")

# %%
#Check the directory

os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Countries of the World (Source - Kaggle)'

# %%
#Import the countries of the world

countries_of_the_world = pd.read_csv('countries of the world.csv')

# %%
#Check the countries of the world

countries_of_the_world
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
#Change directory

os.chdir(r"C:\Users\Idrak\Desktop\Data Science Projects\Climate Change Project\Data\Emissions (Source - World Bank)")

# %%
#Check directory

os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Emissions (Source - World Bank)'

# %%
#Import global emissions

global_emissions = pd.read_csv('global emission data.csv')

# %%
#Check global emissions

global_emissions
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  CO2 emissions (kt)
# 1    Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 2                    Afghanistan          AFG  CO2 emissions (kt)
# 3     Africa Western and Central          AFW  CO2 emissions (kt)
# 4                         Angola          AGO  CO2 emissions (kt)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  CO2 emissions (kt)
# 262                  Yemen, Rep.          YEM  CO2 emissions (kt)
# 263                 South Africa          ZAF  CO2 emissions (kt)
# 264                       Zambia          ZMB  CO2 emissions (kt)
# 265                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...           2012  \
# 0    EN.ATM.CO2E.KT   NaN   NaN   NaN   NaN   NaN   NaN  ...            NaN
# ...

# %%
#Import global emissions country

global_emissions_country = pd.read_csv('global emission country data.csv')

# %%
#Check global emissions country

global_emissions_country
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# ...

# %%
#Change directory

os.chdir(r"C:\Users\Idrak\Desktop\Data Science Projects\Climate Change Project\Data\Gender_Statistics (Source - World Bank)")

# %%
#Check directory

os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\Gender_Statistics (Source - World Bank)'

# %%
#Import gender statistics

gender_statistics = pd.read_csv('gender statistics data.csv')

# %%
#Check gender statistics

gender_statistics
# Out:
#                                            Series Name        Series Code  \
# 0    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 1    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 2    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 3    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 4    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# ..                                                 ...                ...
# 217                                                NaN                NaN
# 218                                                NaN                NaN
# 219                                                NaN                NaN
# 220              Data from database: Gender Statistics                NaN
# 221                           Last Updated: 06/23/2022                NaN
#
#        Country Name Country Code     2012 [YR2012]     2013 [YR2013]  \
# ...

# %%
#Change directory

os.chdir(r'C:\Users\Idrak\Desktop\Data Science Projects\Climate Change Project\Data\World Happiness Report (Source - Kaggle)')

# %%
#Check directory

os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Data\\World Happiness Report (Source - Kaggle)'

# %%
#Import world happiness report

world_happiness_report = pd.read_csv('world-happiness-report.csv')

# %%
#Check world happiness report

world_happiness_report
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
#Import world happiness report 2021

world_happiness_report_2021 = pd.read_csv('world-happiness-report-2021.csv')

# %%
#Check world happiness report 2021

world_happiness_report_2021
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 2. Data Preparation Section:

# %% [markdown]
# 2.1 Changing the data types subsection:

# %%
#Converting data types of countries_of_the_world by replacing ',' with '.' in numbers and making them float.

countries_of_the_world['Pop. Density (per sq. mi.)'] = countries_of_the_world['Pop. Density (per sq. mi.)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Coastline (coast/area ratio)'] = countries_of_the_world['Coastline (coast/area ratio)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Net migration'] = countries_of_the_world['Net migration'].str.replace(',' , '.').astype(float)
countries_of_the_world['Infant mortality (per 1000 births)'] = countries_of_the_world['Infant mortality (per 1000 births)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Literacy (%)'] = countries_of_the_world['Literacy (%)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Phones (per 1000)'] = countries_of_the_world['Phones (per 1000)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Arable (%)'] = countries_of_the_world['Arable (%)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Crops (%)'] = countries_of_the_world['Crops (%)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Other (%)'] = countries_of_the_world['Other (%)'].str.replace(',' , '.').astype(float)
countries_of_the_world['Climate'] = countries_of_the_world['Climate'].str.replace(',' , '.').astype(float)
countries_of_the_world['Birthrate'] = countries_of_the_world['Birthrate'].str.replace(',' , '.').astype(float)
countries_of_the_world['Deathrate'] = countries_of_the_world['Deathrate'].str.replace(',' , '.').astype(float)
countries_of_the_world['Agriculture'] = countries_of_the_world['Agriculture'].str.replace(',' , '.').astype(float)
countries_of_the_world['Industry'] = countries_of_the_world['Industry'].str.replace(',' , '.').astype(float)
countries_of_the_world['Service'] = countries_of_the_world['Service'].str.replace(',' , '.').astype(float)

# %%
#Check the data types of countries_of_the_world

countries_of_the_world.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
#Converting data types of gender_statistics by replacing '..' with '0' in numbers and making them float.

gender_statistics['2012 [YR2012]'] = gender_statistics['2012 [YR2012]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2013 [YR2013]'] = gender_statistics['2013 [YR2013]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2014 [YR2014]'] = gender_statistics['2014 [YR2014]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2015 [YR2015]'] = gender_statistics['2015 [YR2015]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2016 [YR2016]'] = gender_statistics['2016 [YR2016]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2017 [YR2017]'] = gender_statistics['2017 [YR2017]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2018 [YR2018]'] = gender_statistics['2018 [YR2018]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2019 [YR2019]'] = gender_statistics['2019 [YR2019]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2020 [YR2020]'] = gender_statistics['2020 [YR2020]'].str.replace('..', '0', regex=False).astype(float)
gender_statistics['2021 [YR2021]'] = gender_statistics['2021 [YR2021]'].str.replace('..', '0', regex=False).astype(float)

# %%
#Check the data types of gender_statistics

gender_statistics.dtypes
# Out:
# Series Name       object
# Series Code       object
# Country Name      object
# Country Code      object
# 2012 [YR2012]    float64
# 2013 [YR2013]    float64
# 2014 [YR2014]    float64
# 2015 [YR2015]    float64
# 2016 [YR2016]    float64
# 2017 [YR2017]    float64
# 2018 [YR2018]    float64
# 2019 [YR2019]    float64
# 2020 [YR2020]    float64
# 2021 [YR2021]    float64
# dtype: object

# %% [markdown]
# 2.2 Changing the column names subsection:

# %%
#Changing the columns of the countries_of_the_world

countries_of_the_world.columns = ['country', 'region', 'population', 'area_sq_mi',
       'pop_density_per_sqmi', 'coastline_coast_area_ratio',
       'net_migration', 'infant_mortality',
       'GDP_per_capita', 'literacy', 'phones_per_1000', 'arable',
       'crops', 'other', 'climate', 'birthrate', 'deathrate',
       'agriculture', 'industry', 'service']

# %%
#Changing the columns of the global_emissions

global_emissions.columns = ['country_name', 'country_code', 'indicator_name', 'indicator_code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
#Changing the columns of the global_emissions_country

global_emissions_country.columns = ['country_code', 'region', 'income_group', 'table_name']

# %%
#Changing the columns of the gender statistics

gender_statistics.columns = ['series_name', 'series_code', 'country_name', 'country_code',
                             '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

# %%
#Changing the columns of the world_happines_report

world_happiness_report.columns = ['country_name', 'year', 'life_ladder', 'log_gdp_per_capita',
       'social_support', 'healthy_life_expectancy_at_birth',
       'freedom_to_make_life_choices', 'generosity',
       'perceptions_of_corruption', 'positive_affect', 'negative_affect']

# %%
#Changing the columns of the world_happines_report_2021

world_happiness_report_2021.columns = ['country_name', 'regional_indicator', 'ladder_score',
       'standard_error_of_ladder_score', 'upperwhisker', 'lowerwhisker',
       'logged_gdp_per_capita', 'social_support', 'healthy_life_expectancy',
       'freedom_to_make_life_choices', 'generosity',
       'perceptions_of_corruption', 'ladder_score_in_dystopia',
       'explained_by_log_gdp_per_capita', 'explained_by_social_support',
       'explained_by_healthy_life_expectancy',
       'explained_by_freedom_to_make_life_choices',
       'explained_by_generosity', 'explained_by_perceptions_of_corruption',
       'dystopia_plus_residual']

# %% [markdown]
# 2.3 Data cleaning and transformation subsection:

# %%
#Our tables:
#commodity_trade
#world_happiness_report
#world_happiness_report_2021
#gender_statistics
#countries_of_the_world
#global_emissions
#global_emissions_country

# %%
# ----------- CLEANING GLOBAL_EMISSIONS -----------------

# %%
# Pivoting the global_emissions table

global_emissions = global_emissions.melt(id_vars = ['country_name', 'country_code', 'indicator_name', 'indicator_code'],
                                         var_name = 'Year', value_name = 'co2_emissions_kt')

# %%
# Deleting NaN values of global_emissions

global_emissions = global_emissions.dropna(subset = 'co2_emissions_kt')

# %%
# Deleting some columns of global_emissions

global_emissions = global_emissions.drop(['indicator_code', 'indicator_name'], axis=1)

# %%
# ----------- CLEANING GENDER_STATISTICS -----------------

# %%
# Pivoting the gender_statistics table

gender_statistics = gender_statistics.melt(id_vars = ['series_code', 'country_name', 'country_code', 'series_name'],
                       value_vars = ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
                      var_name = 'year', value_name = 'female_male_ratio')

# %%
# Deleting NaN values of the gender_statistics, female_male_ratio

gender_statistics = gender_statistics.dropna(subset = 'female_male_ratio')

# %%
# Deleting 0 values of gender_statistics, female_male_ratio

gender_statistics = gender_statistics.drop(gender_statistics[gender_statistics.female_male_ratio == 0].index)

# %%
# Deleting some columns of gender_statistics table

gender_statistics = gender_statistics.drop(['series_name', 'series_code'], axis=1)

# %%
# ----------- CLEANING WORLD_HAPPINESS_REPORT_2021 -----------------

# %%
# Deleting some columns of world_happiness_report_2021

world_happiness_report_2021 = world_happiness_report_2021.drop(['ladder_score_in_dystopia', 'explained_by_log_gdp_per_capita',
                                                                'explained_by_social_support', 
                                                                'explained_by_healthy_life_expectancy', 
                                                                'explained_by_freedom_to_make_life_choices',
                                                                'explained_by_generosity',
                                                                'explained_by_perceptions_of_corruption',
                                                                'dystopia_plus_residual'], axis=1)

# %%
# ----------- CLEANING COMMODITY_TRADE -----------------

# %%
# Deleting totals of commodity_trade

commodity_trade = commodity_trade.drop(commodity_trade[commodity_trade.comm_code == 'TOTAL'].index)

# %% [markdown]
# ---

# %% [markdown]
# # 3. Data Exporting Section:

# %%
#Our tables:
#commodity_trade.to_csv('commodity_trade.csv')
#world_happiness_report.to_csv('world_happiness_report.csv')
#world_happiness_report_2021.to_csv('world_happiness_report_2021.csv')
#gender_statistics.to_csv('gender_statistics.csv')
#countries_of_the_world.to_csv('countries_of_the_world.csv')
#global_emissions.to_csv('global_emissions.csv')
#global_emissions_country.to_csv('global_emissions_country.csv')

# %%
os.chdir('C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Prepared Data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Idrak\\Desktop\\Data Science Projects\\Climate Change Project\\Prepared Data'
